# %%
# import the library and give it a shorter name 'np'
import numpy as np

# create 100 randomly distributed numbers
X = np.random.normal(size=100)

# transform X into a 2-dimensional array of size 20x5
#X.reshape((20, 5))

# calculate the matrix dot product: X*X', where X' is the transpose of X
#X.dot(X.T)

# %%
# import the packages
import numpy as np
from sklearn.linear_model import LinearRegression

# create some dummy dependent and independent variable
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
y = - 1 * X[:,0] + 2 * X[:,1]

# estimate a linear regression and print out the coefficients
reg = LinearRegression().fit(X, y)
reg.coef_
# Out:
# array([-1.,  2.])

# %%
df = pd.read_csv("../data/Library_Usage.csv",low_memory=False)
df.head()
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals          Age Range  \
# 0                 Senior                5               0  75 years and over
# 1                  Adult                0               0     45 to 54 years
# 2                  Adult                0               0     55 to 59 years
# 3                Welcome                1               1     20 to 24 years
# 4                 Senior                0               0     65 to 74 years
#
#   Home Library Definition Circulation Active Month Circulation Active Year  \
# 0                    Main                      Nov                    2022
# 1                    Main                      Jul                    2023
# 2        Western Addition                      Mar                    2024
# 3                Richmond                      Aug                    2022
# 4                  Sunset                      Mar                    2024
#
# ...

# %%
len(df)
# Out:
# 450359

# %%
df.count()
# Out:
# Patron Type Definition          450359
# Total Checkouts                 450359
# Total Renewals                  450359
# Age Range                       450359
# Home Library Definition         450359
# Circulation Active Month        450359
# Circulation Active Year         450359
# Notice Preference Definition    450359
# Provided Email Address          450359
# Year Patron Registered          450359
# Within San Francisco County     450359
# dtype: int64

# %%
df.min()
# Out:
# Patron Type Definition                 Adult
# Total Checkouts                            0
# Total Renewals                             0
# Age Range                       0 to 9 years
# Home Library Definition                 Anza
# Circulation Active Month                 Apr
# Circulation Active Year                 2004
# Notice Preference Definition           Email
# Provided Email Address                 False
# Year Patron Registered                  2003
# Within San Francisco County            False
# dtype: object

# %%
df = pd.read_csv("../data/Library_Usage.csv",low_memory=False)
df.head()
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals          Age Range  \
# 0                 Senior                5               0  75 years and over
# 1                  Adult                0               0     45 to 54 years
# 2                  Adult                0               0     55 to 59 years
# 3                Welcome                1               1     20 to 24 years
# 4                 Senior                0               0     65 to 74 years
#
#   Home Library Definition Circulation Active Month Circulation Active Year  \
# 0                    Main                      Nov                    2022
# 1                    Main                      Jul                    2023
# 2        Western Addition                      Mar                    2024
# 3                Richmond                      Aug                    2022
# 4                  Sunset                      Mar                    2024
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xc/0ys6f7w12cq2dq1xqlg9nmcm0000gn/T/ipykernel_63348/942532428.py in <module>
# ----> 1 df.len()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'len'

# %%
len(df)
# Out:
# 450359

# %%
df_small=df.head(10)

# %%
df_small
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals          Age Range  \
# 0                 Senior                5               0  75 years and over
# 1                  Adult                0               0     45 to 54 years
# 2                  Adult                0               0     55 to 59 years
# 3                Welcome                1               1     20 to 24 years
# 4                 Senior                0               0     65 to 74 years
# 5                 Senior                0               0  75 years and over
# 6                  Adult                0               0     20 to 24 years
# 7                  Adult                1               0     10 to 19 years
# 8                  Adult                4               4     25 to 34 years
# 9                  Adult                0               0     60 to 64 years
#
#   Home Library Definition Circulation Active Month Circulation Active Year  \
# ...

# %%
df_small.count()
# Out:
# Patron Type Definition          10
# Total Checkouts                 10
# Total Renewals                  10
# Age Range                       10
# Home Library Definition         10
# Circulation Active Month        10
# Circulation Active Year         10
# Notice Preference Definition    10
# Provided Email Address          10
# Year Patron Registered          10
# Within San Francisco County     10
# dtype: int64

# %%
df.to_csv('../data/Library_Usage_Small.csv')

# %%
df_small.to_csv('../data/Library_Usage_Small.csv')

# %%
df = pd.read_csv("../data/Library_Usage_missing_values.csv",low_memory=False)
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53              15
# 1                 5                  Staff              480             378
# 2                 5                  Staff               70              33
# 3                 5                  Staff             3934            2140
# 4                 5                  Staff             1118            1035
#
#         Age Range Home Library Code Home Library Definition  \
# 0             NaN                b2                 Bayview
# 1             NaN                e9               Excelsior
# 2  45 to 54 years                n4              Noe Valley
# 3             NaN                o2              Ocean View
# 4             NaN                o7                  Ortega
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# ...

# %%
df = df[['Patron Type Definition','Total Checkouts','Total Renewals','Age Range','Home Library Definition',
         'Circulation Active Month','Circulation Active Year','Notice Preference Definition',
         'Provided Email Address','Year Patron Registered','Within San Francisco County'
        ]]

# %%
df.head()
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals       Age Range  \
# 0                  Staff               53              15             NaN
# 1                  Staff              480             378             NaN
# 2                  Staff               70              33  45 to 54 years
# 3                  Staff             3934            2140             NaN
# 4                  Staff             1118            1035             NaN
#
#   Home Library Definition Circulation Active Month  Circulation Active Year  \
# 0                 Bayview                      Mar                   2023.0
# 1               Excelsior                      Jun                   2023.0
# 2              Noe Valley                      Jan                   2023.0
# 3              Ocean View                      Jul                   2023.0
# 4                  Ortega                      Jul                   2023.0
#
#   Notice Preference Definition  Provided Email Address  \
# ...

# %%
df = pd.read_csv("../data/Library_Usage_missing_values.csv",low_memory=False)
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 0                  ADULT             1092             761
# 1                 0                  ADULT                0               0
# 2                 0                  ADULT               31              22
# 3                 0                  ADULT                0               0
# 4                 0                  ADULT                0               0
#
#         Age Range Home Library Code Home Library Definition  \
# 0  60 to 64 years                M6                 Mission
# 1  20 to 24 years                P1                    Park
# 2  25 to 34 years                S7                  Sunset
# 3  45 to 54 years                P1                    Park
# 4  25 to 34 years                 X            Main Library
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# ...

# %%
df = df[['Patron Type Definition','Total Checkouts','Total Renewals','Age Range','Home Library Definition',
         'Circulation Active Month','Circulation Active Year','Notice Preference Definition',
         'Provided Email Address','Year Patron Registered'
        ]]

# %%
df.head()
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals       Age Range  \
# 0                  ADULT             1092             761  60 to 64 years
# 1                  ADULT                0               0  20 to 24 years
# 2                  ADULT               31              22  25 to 34 years
# 3                  ADULT                0               0  45 to 54 years
# 4                  ADULT                0               0  25 to 34 years
#
#   Home Library Definition Circulation Active Month Circulation Active Year  \
# 0                 Mission                     July                    2016
# 1                    Park                     None                    None
# 2                  Sunset                    April                    2016
# 3                    Park                     None                    None
# 4            Main Library                     None                    None
#
# ...

# %%
df2=df

# %%
df = pd.read_csv("../data/Library_Usage.csv",low_memory=False)
df.head()
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals          Age Range  \
# 0                 Senior                5               0  75 years and over
# 1                  Adult                0               0     45 to 54 years
# 2                  Adult                0               0     55 to 59 years
# 3                Welcome                1               1     20 to 24 years
# 4                 Senior                0               0     65 to 74 years
#
#   Home Library Definition Circulation Active Month Circulation Active Year  \
# 0                    Main                      Nov                    2022
# 1                    Main                      Jul                    2023
# 2        Western Addition                      Mar                    2024
# 3                Richmond                      Aug                    2022
# 4                  Sunset                      Mar                    2024
#
# ...

# %%
df1=df[['Within San Francisco County'
        ]]

# %%
len(df1)
# Out:
# 450359

# %%
len(df2)
# Out:
# 423448

# %%
df1=df1.sample(n=423448)

# %%
len(df1)
len(df2)
# Out:
# 423448

# %%
df2['Within San Francisco County'] = df1['Within San Francisco County'].values

# %%
df2.head()
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals       Age Range  \
# 0                  ADULT             1092             761  60 to 64 years
# 1                  ADULT                0               0  20 to 24 years
# 2                  ADULT               31              22  25 to 34 years
# 3                  ADULT                0               0  45 to 54 years
# 4                  ADULT                0               0  25 to 34 years
#
#   Home Library Definition Circulation Active Month Circulation Active Year  \
# 0                 Mission                     July                    2016
# 1                    Park                     None                    None
# 2                  Sunset                    April                    2016
# 3                    Park                     None                    None
# 4            Main Library                     None                    None
#
#   Notice Preference Definition  Provided Email Address  \
# ...

# %%
df2.to_csv('../data/Library_Usage_missing_values.csv')

# %%
df = pd.read_csv("../data/Library_Usage_missing_values.csv",low_memory=False)
df.head()
# Out:
#    Unnamed: 0 Patron Type Definition  Total Checkouts  Total Renewals  \
# 0           0                  ADULT             1092             761
# 1           1                  ADULT                0               0
# 2           2                  ADULT               31              22
# 3           3                  ADULT                0               0
# 4           4                  ADULT                0               0
#
#         Age Range Home Library Definition Circulation Active Month  \
# 0  60 to 64 years                 Mission                     July
# 1  20 to 24 years                    Park                     None
# 2  25 to 34 years                  Sunset                    April
# 3  45 to 54 years                    Park                     None
# 4  25 to 34 years            Main Library                     None
#
#   Circulation Active Year Notice Preference Definition  \
# 0                    2016                        phone
# ...

# %%
df = pd.read_csv("../data/Library_Usage.csv")
df['Circulation Active Year'].isna()
# Out:
# /var/folders/xc/0ys6f7w12cq2dq1xqlg9nmcm0000gn/T/ipykernel_63348/2410351682.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Library_Usage.csv")
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 450354    False
# 450355    False
# 450356    False
# 450357    False
# 450358    False
# Name: Circulation Active Year, Length: 450359, dtype: bool

# %%
df = pd.read_csv("../data/Library_Usage.csv", na_values="None")
df['Circulation Active Year']
# Out:
# /var/folders/xc/0ys6f7w12cq2dq1xqlg9nmcm0000gn/T/ipykernel_63348/598481457.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Library_Usage.csv", na_values="None")
# 0         2022
# 1         2023
# 2         2024
# 3         2022
# 4         2024
#           ...
# 450354    Null
# 450355    2022
# 450356    2022
# 450357    2022
# 450358    2023
# Name: Circulation Active Year, Length: 450359, dtype: object

# %%
2019 - df['Circulation Active Year']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ...

# %%
df = pd.read_csv("../data/Library_Usage.csv")
df['Circulation Active Year'] = pd.to_numeric(df['Circulation Active Year'], errors='coerce')
df['Circulation Active Year']
# Out:
# /var/folders/xc/0ys6f7w12cq2dq1xqlg9nmcm0000gn/T/ipykernel_63348/3757504680.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Library_Usage.csv")
# 0         2022.0
# 1         2023.0
# 2         2024.0
# 3         2022.0
# 4         2024.0
#            ...
# 450354       NaN
# 450355    2022.0
# 450356    2022.0
# 450357    2022.0
# 450358    2023.0
# Name: Circulation Active Year, Length: 450359, dtype: float64

# %%
2019 - df['Circulation Active Year']
# Out:
# 0        -3.0
# 1        -4.0
# 2        -5.0
# 3        -3.0
# 4        -5.0
#          ...
# 450354    NaN
# 450355   -3.0
# 450356   -3.0
# 450357   -3.0
# 450358   -4.0
# Name: Circulation Active Year, Length: 450359, dtype: float64

# %%
import pandas as pd

df = pd.read_csv("../data/Library_Usage.csv",low_memory=False)
df['Circulation Active Year']
# Out:
# 0         2022
# 1         2023
# 2         2024
# 3         2022
# 4         2024
#           ...
# 450354    Null
# 450355    2022
# 450356    2022
# 450357    2022
# 450358    2023
# Name: Circulation Active Year, Length: 450359, dtype: object

# %%
2019 - df['Circulation Active Year']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ...

# %%
df = pd.read_csv("../data/Library_Usage.csv",low_memory=False,na_values="Null")
df['Circulation Active Year']
# Out:
# 0         2022.0
# 1         2023.0
# 2         2024.0
# 3         2022.0
# 4         2024.0
#            ...
# 450354       NaN
# 450355    2022.0
# 450356    2022.0
# 450357    2022.0
# 450358    2023.0
# Name: Circulation Active Year, Length: 450359, dtype: float64

# %%
2019 - df['Circulation Active Year']
# Out:
# 0        -3.0
# 1        -4.0
# 2        -5.0
# 3        -3.0
# 4        -5.0
#          ...
# 450354    NaN
# 450355   -3.0
# 450356   -3.0
# 450357   -3.0
# 450358   -4.0
# Name: Circulation Active Year, Length: 450359, dtype: float64

# %%
df = pd.read_csv("../data/Library_Usage.csv",low_memory=False)

# %%
#df[df['Age Range'].isna()]
df[df['Age Range'].notna()]
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                      Senior                5               0
# 1                       Adult                0               0
# 2                       Adult                0               0
# 3                     Welcome                1               1
# 4                      Senior                0               0
# ...                       ...              ...             ...
# 450354    Digital Access Card                0               0
# 450355    Digital Access Card                0               0
# 450356    Digital Access Card                0               0
# 450357    Digital Access Card                0               0
# 450358    Digital Access Card                0               0
#
#                 Age Range Home Library Definition Circulation Active Month  \
# 0       75 years and over                    Main                      Nov
# ...

# %%
df.isna().sum()
# Out:
# Patron Type Definition          0
# Total Checkouts                 0
# Total Renewals                  0
# Age Range                       0
# Home Library Definition         0
# Circulation Active Month        0
# Circulation Active Year         0
# Notice Preference Definition    0
# Provided Email Address          0
# Year Patron Registered          0
# Within San Francisco County     0
# dtype: int64

# %%
df.loc[df['Circulation Active Month'] == 'Null']
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 14               Teacher Card                0               0
# 17               Teacher Card                0               0
# 36                     Senior                0               0
# 93                     Senior                0               0
# 127                    Senior                0               0
# ...                       ...              ...             ...
# 450321    Digital Access Card                0               0
# 450324    Digital Access Card                0               0
# 450339    Digital Access Card                0               0
# 450340    Digital Access Card                0               0
# 450354    Digital Access Card                0               0
#
#                 Age Range Home Library Definition Circulation Active Month  \
# 14           0 to 9 years                    Main                     Null
# ...

# %%
#row_filter = (df['Patron Type Definition'] == 'Senior')

# %%
df = pd.read_csv("../data/Library_Usage.csv",low_memory=False)

# %%
row_filter = (df['Age Range'] == 'Null')

# %%
df.loc[row_filter]
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals Age Range  \
# 2010                    Adult                0               0      Null
# 3603      Digital Access Card                0               0      Null
# 5212                    Adult                5               4      Null
# 5523                    Adult                0               0      Null
# 6521                    Adult                0               0      Null
# ...                       ...              ...             ...       ...
# 450329    Digital Access Card                0               0      Null
# 450331    Digital Access Card                0               0      Null
# 450333    Digital Access Card                0               0      Null
# 450336    Digital Access Card                0               0      Null
# 450350    Digital Access Card                0               0      Null
#
#        Home Library Definition Circulation Active Month  \
# ...

# %%
df = pd.read_csv("../data/Library_Usage.csv", low_memory=False)

# %%
df[df['Age Range'].isna()]
#df[df['Age Range'].notna()]
# Out:
# Empty DataFrame
# Columns: [Patron Type Definition, Total Checkouts, Total Renewals, Age Range, Home Library Definition, Circulation Active Month, Circulation Active Year, Notice Preference Definition, Provided Email Address, Year Patron Registered, Within San Francisco County]
# Index: []

# %%
df = pd.read_csv("../data/Library_Usage.csv", low_memory=False, na_values="Null")

# %%
#df[df['Age Range'].isna()]
df[df['Age Range'].notna()]
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                      Senior                5               0
# 1                       Adult                0               0
# 2                       Adult                0               0
# 3                     Welcome                1               1
# 4                      Senior                0               0
# ...                       ...              ...             ...
# 450354    Digital Access Card                0               0
# 450355    Digital Access Card                0               0
# 450356    Digital Access Card                0               0
# 450357    Digital Access Card                0               0
# 450358    Digital Access Card                0               0
#
#                 Age Range Home Library Definition Circulation Active Month  \
# 0       75 years and over                    Main                      Nov
# ...

# %%
df.isna().sum()
# Out:
# Patron Type Definition              0
# Total Checkouts                     0
# Total Renewals                      0
# Age Range                         510
# Home Library Definition            30
# Circulation Active Month        40317
# Circulation Active Year         40317
# Notice Preference Definition     3315
# Provided Email Address              0
# Year Patron Registered              0
# Within San Francisco County       221
# dtype: int64

# %%
df.isna().sum()
# Out:
# Patron Type Definition              0
# Total Checkouts                     0
# Total Renewals                      0
# Age Range                         510
# Home Library Definition            30
# Circulation Active Month        40317
# Circulation Active Year         40317
# Notice Preference Definition     3315
# Provided Email Address              0
# Year Patron Registered              0
# Within San Francisco County       221
# dtype: int64

# %%
# drops all rows that contain at least one missing values
df.dropna()
# drops all missing values in this series
df['Age Range'].dropna()
# Out:
# 0         75 years and over
# 1            45 to 54 years
# 2            55 to 59 years
# 3            20 to 24 years
# 4            65 to 74 years
#                 ...
# 450354       35 to 44 years
# 450355       45 to 54 years
# 450356       25 to 34 years
# 450357       35 to 44 years
# 450358       65 to 74 years
# Name: Age Range, Length: 449849, dtype: object

# %%
df['Age Range'].fillna("keine Angabe")
# Out:
# 0         75 years and over
# 1            45 to 54 years
# 2            55 to 59 years
# 3            20 to 24 years
# 4            65 to 74 years
#                 ...
# 450354       35 to 44 years
# 450355       45 to 54 years
# 450356       25 to 34 years
# 450357       35 to 44 years
# 450358       65 to 74 years
# Name: Age Range, Length: 450359, dtype: object

# %%
import pandas as pd
df = pd.read_csv('../data/Library_Usage.csv',
                 low_memory=False
                )

# %%
df.head()
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals          Age Range  \
# 0                 Senior                5               0  75 years and over
# 1                  Adult                0               0     45 to 54 years
# 2                  Adult                0               0     55 to 59 years
# 3                Welcome                1               1     20 to 24 years
# 4                 Senior                0               0     65 to 74 years
#
#   Home Library Definition Circulation Active Month Circulation Active Year  \
# 0                    Main                      Nov                    2022
# 1                    Main                      Jul                    2023
# 2        Western Addition                      Mar                    2024
# 3                Richmond                      Aug                    2022
# 4                  Sunset                      Mar                    2024
#
# ...

# %%
len(df) - df.count()
# Out:
# Patron Type Definition          0
# Total Checkouts                 0
# Total Renewals                  0
# Age Range                       0
# Home Library Definition         0
# Circulation Active Month        0
# Circulation Active Year         0
# Notice Preference Definition    0
# Provided Email Address          0
# Year Patron Registered          0
# Within San Francisco County     0
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv",low_memory=False)
df.head()
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals          Age Range  \
# 0                 Senior                5               0  75 years and over
# 1                  Adult                0               0     45 to 54 years
# 2                  Adult                0               0     55 to 59 years
# 3                Welcome                1               1     20 to 24 years
# 4                 Senior                0               0     65 to 74 years
#
#   Home Library Definition Circulation Active Month Circulation Active Year  \
# 0                    Main                      Nov                    2022
# 1                    Main                      Jul                    2023
# 2        Western Addition                      Mar                    2024
# 3                Richmond                      Aug                    2022
# 4                  Sunset                      Mar                    2024
#
# ...

# %%
df.tail()
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 450354    Digital Access Card                0               0
# 450355    Digital Access Card                0               0
# 450356    Digital Access Card                0               0
# 450357    Digital Access Card                0               0
# 450358    Digital Access Card                0               0
#
#              Age Range Home Library Definition Circulation Active Month  \
# 450354  35 to 44 years               Ingleside                     Null
# 450355  45 to 54 years               Ingleside                      Aug
# 450356  25 to 34 years               Ingleside                      Aug
# 450357  35 to 44 years               Ingleside                      Apr
# 450358  65 to 74 years                 Bayview                      Apr
#
#        Circulation Active Year Notice Preference Definition  \
# 450354                    Null                        Email
# ...

# %%
df.describe()
# Out:
#        Total Checkouts  Total Renewals  Year Patron Registered
# count    450359.000000   450359.000000           450359.000000
# mean        155.218053       78.968929             2016.094902
# std         526.242567      305.915233                6.278639
# min           0.000000        0.000000             2003.000000
# 25%           0.000000        0.000000             2012.000000
# 50%           7.000000        3.000000             2018.000000
# 75%          74.000000       36.000000             2021.000000
# max       39743.000000    12730.000000             2023.000000

# %%
df.describe(include='all')
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# count                  450359    450359.000000   450359.000000
# unique                     17              NaN             NaN
# top                     Adult              NaN             NaN
# freq                   284671              NaN             NaN
# mean                      NaN       155.218053       78.968929
# std                       NaN       526.242567      305.915233
# min                       NaN         0.000000        0.000000
# 25%                       NaN         0.000000        0.000000
# 50%                       NaN         7.000000        3.000000
# 75%                       NaN        74.000000       36.000000
# max                       NaN     39743.000000    12730.000000
#
#              Age Range Home Library Definition Circulation Active Month  \
# count           450359                  450359                   450359
# ...

# %%
print(df.min())
print(df['Total Renewals'].min())
# Out:
# Patron Type Definition                 Adult
# Total Checkouts                            0
# Total Renewals                             0
# Age Range                       0 to 9 years
# Home Library Definition                 Anza
# Circulation Active Month                 Apr
# Circulation Active Year                 2004
# Notice Preference Definition           Email
# Provided Email Address                 False
# Year Patron Registered                  2003
# Within San Francisco County            False
# dtype: object
# 0

# %%
df['Total Renewals'].sum()
df['Total Renewals'].between(100, 200).sum()
# Out:
# 25835

# %%
df.columns
df.dtypes
df.shape
# Out:
# (450359, 11)

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv",low_memory=False)
df.head()
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals          Age Range  \
# 0                 Senior                5               0  75 years and over
# 1                  Adult                0               0     45 to 54 years
# 2                  Adult                0               0     55 to 59 years
# 3                Welcome                1               1     20 to 24 years
# 4                 Senior                0               0     65 to 74 years
#
#   Home Library Definition Circulation Active Month Circulation Active Year  \
# 0                    Main                      Nov                    2022
# 1                    Main                      Jul                    2023
# 2        Western Addition                      Mar                    2024
# 3                Richmond                      Aug                    2022
# 4                  Sunset                      Mar                    2024
#
# ...

# %%
#zum Vergleich:
import pandas as pd
df = pd.read_csv('../data/Library_Usage.csv',na_values="Null",
                 low_memory=False
                )

# %%
#zum Vergleich:
import pandas as pd
df = pd.read_csv('../data/Library_Usage.csv',na_values="Null",
                 low_memory=False
                )

# %%
#df.isna().sum()
df['Age Range'].isna().sum()
# Out:
# 510

# %%
df = df.dropna()

# %%
df['Circulation Active Year'].dtype
# Out:
# dtype('float64')

# %%
pd.to_numeric(
  df['Circulation Active Year'], errors='coerce'
)
# Out:
# 0         2022.0
# 1         2023.0
# 2         2024.0
# 3         2022.0
# 4         2024.0
#            ...
# 450133    2020.0
# 450134    2024.0
# 450135    2023.0
# 450136    2021.0
# 450137    2022.0
# Name: Circulation Active Year, Length: 406993, dtype: float64

# %%
row_filter = (df['Age Range'] == '60 to 64 years') & (df['Circulation Active Year'] == 2016)
df.loc[row_filter]
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 2569                    Adult                2               0
# 6582                    Adult               11              24
# 30085                   Adult                3               0
# 45433                   Adult               21               5
# 108311                  Adult               56               2
# 116078                  Adult               96               2
# 117973                  Adult               13               0
# 211971                  Adult                3               3
# 232885                  Adult               51               4
# 233915                  Adult               80               4
# 244151                  Adult                4               0
# 285449                  Adult             2408            2331
# 328217                  Adult                1               2
# 328412                  Adult               12               7
# ...

# %%
df1=(df['Age Range'] == '60 to 64 years') & (df['Circulation Active Year'] == 2016)

# %%
df1.value_counts()
# Out:
# False    406977
# True         16
# dtype: int64

# %%
len(df[(df['Age Range'] == '60 to 64 years') & (df['Circulation Active Year'] == 2016)])
# Out:
# 16

# %%
df['Age Range'].isna().sum()
# Out:
# 0

# %%
df.shape[0]
# Out:
# 450359

# %%
import pandas as pd
df = pd.read_csv('../data/Library_Usage.csv',na_values="Null",
                 low_memory=False
                )

# %%
import pandas as pd
df = pd.read_csv('../data/Library_Usage.csv',na_values="Null",
                 low_memory=False
                )
df['Age Range'].value_counts()
# Out:
# 25 to 34 years       95278
# 35 to 44 years       85669
# 10 to 19 years       67758
# 45 to 54 years       49820
# 0 to 9 years         33180
# 65 to 74 years       32455
# 20 to 24 years       27145
# 75 years and over    20721
# 55 to 59 years       19735
# 60 to 64 years       18088
# Name: Age Range, dtype: int64

# %%
df['Age Range'].value_counts(normalize=True)
# Out:
# 25 to 34 years       0.211800
# 35 to 44 years       0.190439
# 10 to 19 years       0.150624
# 45 to 54 years       0.110748
# 0 to 9 years         0.073758
# 65 to 74 years       0.072146
# 20 to 24 years       0.060342
# 75 years and over    0.046062
# 55 to 59 years       0.043870
# 60 to 64 years       0.040209
# Name: Age Range, dtype: float64

# %%
age_mode = df['Age Range'].mode()
age_mode[0]
# Out:
# '25 to 34 years'

# %%
df['Age Range'].isna().sum()
# Out:
# 510

# %%
age_range_mode = df['Age Range'].mode()[0]
df['Age Range'].fillna(age_range_mode, inplace=True)

# %%
df['Age Range'].isna().sum()
# Out:
# 0

# %%
df['Total Renewals'].agg(lambda x: x.std()/x.mean())
# Out:
# 3.873868313954441

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv",low_memory=False)
df['Total Checkouts'].mean()
# Out:
# 155.218052709061

# %%
df['Total Checkouts'].median()
# Out:
# 7.0

# %%
df['Total Checkouts'].quantile(q=[0.25, 0.5, 0.75])
# Out:
# 0.25     0.0
# 0.50     7.0
# 0.75    74.0
# Name: Total Checkouts, dtype: float64

# %%
# identifies 0.5% of the data at both ends of the distribution
alpha = 0.005
df['Total Checkouts'].quantile([alpha, 1-alpha])
# Out:
# 0.005       0.0
# 0.995    3255.0
# Name: Total Checkouts, dtype: float64

# %%
df['Total Checkouts'].var()
# Out:
# 276931.23963427445

# %%
df['Total Checkouts'].std()
# Out:
# 526.2425672959899

# %%
df['Total Checkouts'].std()/df['Total Checkouts'].mean()
# Out:
# 3.390343829930486

# %%
df['Total Renewals'].std()/df['Total Renewals'].mean()
# Out:
# 3.873868313954441

# %%
df['Total Checkouts'].max() - df['Total Checkouts'].min()
# Out:
# 39743

# %%
df['Total Checkouts'].var()
# Out:
# 276931.23963427445

# %%
df['Total Checkouts'].std()
# Out:
# 526.2425672959899

# %%
df['Total Checkouts'].max() - df['Total Checkouts'].min()
# Out:
# 39743

# %%
df['Total Checkouts'].quantile(q=0.75) - df['Total Checkouts'].quantile(q=0.25)
# Out:
# 74.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

import pandas as pd

df = pd.read_csv("../data/Library_Usage.csv",low_memory=False,na_values="Null",)
df = df[df['Total Checkouts'] < 816]
plt.figure(figsize=(16, 6))
plt = sns.boxplot(y='Total Checkouts', x='Year Patron Registered', data=df, fliersize=0.5, whis=1.5)
plt.get_figure().savefig("boxplots.png")

# %%
import pandas as pd

df = pd.read_csv(
    "../data/Library_Usage.csv", 
    low_memory=False,
    na_values="Null"
)
pd.crosstab(
    df['Notice Preference Definition'],
    df['Age Range'],
    margins=True
)
# Out:
# Age Range                     0 to 9 years  10 to 19 years  20 to 24 years  \
# Notice Preference Definition
# Email                                30075           56115           24544
# Phone                                 1580           10494            2150
# Print                                 1030             628             263
# All                                  32685           67237           26957
#
# Age Range                     25 to 34 years  35 to 44 years  45 to 54 years  \
# Notice Preference Definition
# Email                                  90890           81600           46797
# Phone                                   2675            2452            2122
# Print                                   1000             968             596
# All                                    94565           85020           49515
#
# Age Range                     55 to 59 years  60 to 64 years  65 to 74 years  \
# Notice Preference Definition
# ...

# %%
pd.crosstab(
    df['Notice Preference Definition'],
    df['Age Range'],
    margins=True, normalize=1
)
# Out:
# Age Range                     0 to 9 years  10 to 19 years  20 to 24 years  \
# Notice Preference Definition
# Email                             0.920147        0.834585        0.910487
# Phone                             0.048340        0.156075        0.079757
# Print                             0.031513        0.009340        0.009756
#
# Age Range                     25 to 34 years  35 to 44 years  45 to 54 years  \
# Notice Preference Definition
# Email                               0.961138        0.959774        0.945108
# Phone                               0.028287        0.028840        0.042856
# Print                               0.010575        0.011386        0.012037
#
# Age Range                     55 to 59 years  60 to 64 years  65 to 74 years  \
# Notice Preference Definition
# Email                               0.921533        0.895586        0.866095
# Phone                               0.064252        0.087772        0.114501
# ...

# %%
pd.crosstab(
    df['Notice Preference Definition'],
    df['Age Range'],
    margins=True, normalize=0
)
# Out:
# Age Range                     0 to 9 years  10 to 19 years  20 to 24 years  \
# Notice Preference Definition
# Email                             0.073601        0.137327        0.060065
# Phone                             0.049863        0.331177        0.067851
# Print                             0.165276        0.100770        0.042202
# All                               0.073196        0.150573        0.060368
#
# Age Range                     25 to 34 years  35 to 44 years  45 to 54 years  \
# Notice Preference Definition
# Email                               0.222431        0.199696        0.114524
# Phone                               0.084419        0.077382        0.066968
# Print                               0.160462        0.155327        0.095635
# All                                 0.211772        0.190397        0.110886
#
# Age Range                     55 to 59 years  60 to 64 years  65 to 74 years  \
# Notice Preference Definition
# ...

# %%
# Creating an empty dataframe
df = pd.DataFrame(columns=['a', 'b'])

# Appending a row
#df = df.append({ 'a': 1, 'b': 2 }, ignore_index=True)

# Create the new row as its own dataframe
#df_new_row = pd.DataFrame({ 'a': [1], 'b': [2] })
#df = pd.concat([df, df_new_row])

#df = pd.concat([df, pd.DataFrame.from_records([{ 'a': 1, 'b': 2 }])])

# %%
df
# Out:
# Empty DataFrame
# Columns: [a, b]
# Index: []

# %%
df = df.append({ 'a': 1, 'b': 2 }, ignore_index=True)
# Out:
# /var/folders/xc/0ys6f7w12cq2dq1xqlg9nmcm0000gn/T/ipykernel_68234/514073532.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({ 'a': 1, 'b': 2 }, ignore_index=True)

# %%
df
# Out:
#    a  b
# 0  1  2

# %%
dat = dat.append(pd.DataFrame(X, columns=["x", "y", "correlation"]))
#df = pd.concat([df, pd.DataFrame.from_records([{ 'a': 1, 'b': 2 }])])

# %%
import pandas as pd

df = pd.read_csv("../data/Library_Usage.csv",low_memory=False,na_values="Null",)
df['Total Checkouts'].corr(df['Total Renewals'])
# Out:
# 0.6421628513121923

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.set_theme()

# use sample to generate a random subsample
df = pd.read_csv("../data/Library_Usage.csv",low_memory=False,na_values="Null")

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', data=df)

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', data=df,
            height=5, aspect=3)

# %%
plt.savefig('../tutorial.png', dpi=150)

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', 
                hue='Provided Email Address', style='Within San Francisco County', 
                size='Year Patron Registered', data=df)

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', 
            size='Year Patron Registered',
            row='Provided Email Address', col='Within San Francisco County', data=df)

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', 
            hue='Provided Email Address', 
            col='Within San Francisco County',
            palette=sns.color_palette('Accent', 2), 
            data=df)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# matplotlib inline
sns.set_theme()

df = pd.read_csv("../data/Library_Usage.csv",low_memory=False,na_values="Null")

# %%
sns.catplot(y='Year Patron Registered',
            data=df, kind='count', color="steelblue")

# %%
sns.catplot(y='Age Range', hue='Provided Email Address', 
            data=df, kind='count')

# %%
sns.catplot(x='Patron Type Definition', 
            data=df, kind='count', 
            col='Year Patron Registered', col_wrap=4)

# %%
# Histogram

sns.distplot(df['Total Renewals'], kde=False)

# With density estimation

sns.distplot(df['Total Renewals'], kde=True)
# Out:
# <AxesSubplot:xlabel='Total Renewals', ylabel='Density'>

# %%
df['Provided Email Address'][df['Age Range'] == '0 to 9 years'].sum()
# Out:
# 30010

# %%
df['Total Checkouts'].quantile(0.60)
# Out:
# 18.0

# %%
df['Provided Email Address'].value_counts()
# Out:
# True     408532
# False     41827
# Name: Provided Email Address, dtype: int64

# %%
pd.crosstab(
    df['Provided Email Address'],
    df['Age Range'],
    margins=True#, normalize=1
)
# Out:
# Age Range               0 to 9 years  10 to 19 years  20 to 24 years  \
# Provided Email Address
# False                           3170           11543            2611
# True                           30010           56215           24534
# All                            33180           67758           27145
#
# Age Range               25 to 34 years  35 to 44 years  45 to 54 years  \
# Provided Email Address
# False                             4565            4258            3119
# True                             90713           81411           46701
# All                              95278           85669           49820
#
# Age Range               55 to 59 years  60 to 64 years  65 to 74 years  \
# Provided Email Address
# False                             1683            2024            4502
# True                             18052           16064           27953
# All                              19735           18088           32455
#
# ...

# %%
pd.crosstab(
    df['Provided Email Address'],
    df['Age Range'],
    margins=True, normalize=1
)
# Out:
# Age Range               0 to 9 years  10 to 19 years  20 to 24 years  \
# Provided Email Address
# False                       0.095539        0.170356        0.096187
# True                        0.904461        0.829644        0.903813
#
# Age Range               25 to 34 years  35 to 44 years  45 to 54 years  \
# Provided Email Address
# False                         0.047912        0.049703        0.062605
# True                          0.952088        0.950297        0.937395
#
# Age Range               55 to 59 years  60 to 64 years  65 to 74 years  \
# Provided Email Address
# False                          0.08528        0.111897        0.138715
# True                           0.91472        0.888103        0.861285
#
# Age Range               75 years and over       All
# Provided Email Address
# False                            0.205878  0.092789
# True                             0.794122  0.907211

# %%
df['Total Checkouts'].quantile(0.60)
# Out:
# 18.0

# %%
df['Age Range'].mode()
# Out:
# 0    25 to 34 years
# Name: Age Range, dtype: object

# %%
df['Total Renewals'].quantile([0.25, 0.75]).diff()
# Out:
# 0.25     NaN
# 0.75    36.0
# Name: Total Renewals, dtype: float64
